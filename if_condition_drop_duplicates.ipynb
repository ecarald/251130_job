# %%
# Cleansing of the silver table consisting of removing duplicates and overwrite the table

df = spark.sql("""
SELECT DISTINCT * FROM job_catalog.default.silver_customers_sales""")
#display(df)

df.write.mode("overwrite").saveAsTable("job_catalog.default.silver_customers_sales")
